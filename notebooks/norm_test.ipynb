# %%
import clip
import torch
import torch.nn.functional as F
from PIL import Image

# %%
clip_model, preprocess = clip.load("ViT-B/32")

# %%
img1 = Image.open("../img1.png")
img2 = Image.open("../img2.png")

img1 = preprocess(img1)
img2 = preprocess(img2)

# %%
clip1, clip2 = clip_model.encode_image(torch.stack([img1, img2]).cuda())

(clip1 - clip2).norm(p=2)

F.normalize(clip1, dim=0) @ F.normalize(clip2, dim=0).T
# Out:
# /tmp/ipykernel_251680/965597899.py:5: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /__w/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:4314.)
#   F.normalize(clip1, dim=0) @ F.normalize(clip2, dim=0).T
# tensor(0.6978, device='cuda:0', dtype=torch.float16, grad_fn=<DotBackward0>)
