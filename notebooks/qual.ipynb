# %%
from datasets import load_dataset
import json

# %%
imagenet100_dataset = load_dataset("clane9/imagenet-100", cache_dir="../hf_cache/", split="validation")
# Out:
# ...
# Resolving data files:   0%|          | 0/17 [00:00<?, ?it/s]

# %%
text_labels = imagenet100_dataset.features['label'].names

# %%
from labels import IMAGENET2012_CLASSES

with open('../experiment_results/m_honesty/ca_sa_v2.json') as f:
    claims = json.load(f)

grouped_classes = [[list(IMAGENET2012_CLASSES.values())[idx] for idx in f['claimed_classes']] for f in claims['features']]

for i, g in enumerate(grouped_classes):
    print(i, " | ".join(g))
# Out:
# 0 prison, prison house | radio telescope, radio reflector | mosque | castle | triumphal arch | bell cote, bell cot | dome
# 1 bookshop, bookstore, bookstall | grocery store, grocery, food market, market | carpenter's kit, tool kit | bakery, bakeshop, bakehouse | medicine chest, medicine cabinet
# 2 sea urchin | lionfish | car mirror
# 3 pot, flowerpot | upright, upright piano | Polaroid camera, Polaroid Land camera
# 4 bee eater | bustard | kit fox, Vulpes macrotis
# 5 organ, pipe organ | microphone, mike | passenger car, coach, carriage | oscilloscope, scope, cathode-ray oscilloscope, CRO | steam locomotive | carpenter's kit, tool kit
# 6 toucan | junco, snowbird | guinea pig, Cavia cobaya | basset, basset hound
# 7 wood rabbit, cottontail, cottontail rabbit | llama | hare | orangutan, orang, orangutang, Pongo pygmaeus
# 8 electric guitar | organ, pipe organ | bookshop, bookstore, bookstall | confectionery, confectionary, candy store
# ...

# %%
feat = 110
